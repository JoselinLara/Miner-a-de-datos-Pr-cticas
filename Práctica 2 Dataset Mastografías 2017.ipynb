# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
#https://datos.gob.mx/busca/dataset/cancer-de-la-mujer-sicam-cancer-de-mama
path = 'C:\\Users\\hades\\Downloads\\dataset práctica 1\\Mastografías 2017.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
# 1                1  AGUASCALIENTES    57          00:00.0
# 2                1  AGUASCALIENTES    57          00:00.0
# 3                1  AGUASCALIENTES    57          00:00.0
# 4                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto                         Resultado
# 0                    00:00.0  Altamente Sugestiva a Malignidad
# 1                    00:00.0  Altamente Sugestiva a Malignidad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855017 entries, 0 to 855016
# Data columns (total 10 columns):
# Clave Entidad                 855017 non-null int64
# Entidad                       855017 non-null object
# Clave Jurisdicción            855017 non-null int64
# Jurisdicción                  855017 non-null object
# Clave Municipio               855017 non-null int64
# Municipio                     855017 non-null object
# Edad                          855017 non-null int64
# Fecha Toma Masto              855017 non-null object
# Fecha Interpretación Masto    855017 non-null object
# Resultado                     855017 non-null object
# dtypes: int64(4), object(6)
# memory usage: 65.2+ MB

# %%
df.shape
# Out:
# (855017, 10)

# %%
df.shape[0]
# Out:
# 855017

# %%
df.shape[1]
# Out:
# 10

# %%
df.columns.values.tolist()
# Out:
# ['Clave Entidad',
#  'Entidad',
#  'Clave Jurisdicción',
#  'Jurisdicción',
#  'Clave Municipio',
#  'Municipio',
#  'Edad',
#  'Fecha Toma Masto',
#  'Fecha Interpretación Masto',
#  'Resultado']

# %%
df.dtypes
# Out:
# Clave Entidad                  int64
# Entidad                       object
# Clave Jurisdicción             int64
# Jurisdicción                  object
# Clave Municipio                int64
# Municipio                     object
# Edad                           int64
# Fecha Toma Masto              object
# Fecha Interpretación Masto    object
# Resultado                     object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
df.describe()
# Out:
#        Clave Entidad  Clave Jurisdicción  Clave Municipio           Edad
# count  855017.000000       855017.000000    855017.000000  855017.000000
# mean       16.195659            5.270046        41.729113      50.756363
# std         7.068885            5.228078        39.831590       7.558090
# min         1.000000            1.000000         1.000000      25.000000
# 25%        11.000000            1.000000         9.000000      44.000000
# 50%        15.000000            4.000000        30.000000      50.000000
# 75%        21.000000            7.000000        67.000000      56.000000
# max        32.000000           71.000000       553.000000      69.000000

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
df.loc[[0]]
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto                         Resultado
# 0                    00:00.0  Altamente Sugestiva a Malignidad

# %%
df[100:].head() #df.tail(-100) )
# Out:
#      Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 100              1  Aguascalientes                   1  Aguascalientes
# 101              1  Aguascalientes                   1  Aguascalientes
# 102              1  Aguascalientes                   1  Aguascalientes
# 103              1  Aguascalientes                   1  Aguascalientes
# 104              1  Aguascalientes                   1  Aguascalientes
#
#      Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 100                1  AGUASCALIENTES    58          00:00.0
# 101                1  AGUASCALIENTES    48          00:00.0
# 102                1  AGUASCALIENTES    66          00:00.0
# 103                1  AGUASCALIENTES    44          00:00.0
# 104                1  AGUASCALIENTES    63          00:00.0
#
#     Fecha Interpretación Masto Resultado
# 100                    00:00.0   Benigna
# 101                    00:00.0   Benigna
# 102                    00:00.0   Benigna
# ...

# %%
df.Resultado.values
# Out:
# array(['Altamente Sugestiva a Malignidad',
#        'Altamente Sugestiva a Malignidad', 'Probablemente Benigna', ...,
#        'Benigna', 'Evaluación Adicional', 'Benigna'], dtype=object)

# %%
df.Resultado.unique()
# Out:
# array(['Altamente Sugestiva a Malignidad', 'Probablemente Benigna',
#        'Evaluación Adicional', 'Benigna', 'Anormalidad Sospechosa',
#        'Riesgo Intermedio de Malignidad', 'Baja Sospecha de Malignidad',
#        'Negativa', 'Riesgo Moderado de Malignidad'], dtype=object)

# %%
df.Resultado.value_counts()
# Out:
# Benigna                             629186
# Negativa                            126158
# Evaluación Adicional                 69369
# Probablemente Benigna                23527
# Anormalidad Sospechosa                3494
# Altamente Sugestiva a Malignidad      1331
# Baja Sospecha de Malignidad            855
# Riesgo Intermedio de Malignidad        753
# Riesgo Moderado de Malignidad          344
# Name: Resultado, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          Clave Entidad  Entidad  Clave Jurisdicción  Jurisdicción  \
# count           855017   855017              855017        855017
# size            855017   855017              855017        855017
# nunique             32       32                  21           200
#
#          Clave Municipio  Municipio    Edad  Fecha Toma Masto  \
# count             855017     855017  855017            855017
# size              855017     855017  855017            855017
# nunique              139        360      45               283
#
#          Fecha Interpretación Masto  Resultado
# count                        855017     855017
# size                         855017     855017
# nunique                       35615          9

# %%
df.groupby('Resultado').agg(['count', 'size', 'nunique']).stack()
# Out:
#                                           Clave Entidad  Entidad  \
# Resultado
# Altamente Sugestiva a Malignidad count             1331     1331
#                                  size              1331     1331
#                                  nunique             31       31
# Anormalidad Sospechosa           count             3494     3494
#                                  size              3494     3494
#                                  nunique             32       32
# Baja Sospecha de Malignidad      count              855      855
#                                  size               855      855
#                                  nunique             30       30
# Benigna                          count           629186   629186
#                                  size            629186   629186
#                                  nunique             32       32
# Evaluación Adicional             count            69369    69369
# ...

# %%
df.groupby('Resultado').agg(['count', 'size', 'nunique'])
# Out:
#                                  Clave Entidad                 Entidad  \
#                                          count    size nunique   count
# Resultado
# Altamente Sugestiva a Malignidad          1331    1331      31    1331
# Anormalidad Sospechosa                    3494    3494      32    3494
# Baja Sospecha de Malignidad                855     855      30     855
# Benigna                                 629186  629186      32  629186
# Evaluación Adicional                     69369   69369      32   69369
# Negativa                                126158  126158      32  126158
# Probablemente Benigna                    23527   23527      32   23527
# Riesgo Intermedio de Malignidad            753     753      29     753
# Riesgo Moderado de Malignidad              344     344      28     344
#
#                                                  Clave Jurisdicción          \
#                                     size nunique              count    size
# Resultado
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#         Clave Entidad           Entidad  Clave Jurisdicción  \
# 304116             14           Jalisco                   4
# 92917               9  Ciudad de México                   1
# 574505             19        Nuevo León                   1
# 472539             15  Estado de México                  18
# 584796             19        Nuevo León                   4
#
#              Jurisdicción  Clave Municipio          Municipio  Edad  \
# 304116           La Barca               96    TIZAPAN EL ALTO    43
# 92917   Gustavo A. Madero                5  GUSTAVO A. MADERO    45
# 574505          Monterrey               39          MONTERREY    51
# 472539     Nezahualcoyotl               58     NEZAHUALCOYOTL    48
# 584796   Ciudad Guadalupe               26          GUADALUPE    47
#
#        Fecha Toma Masto Fecha Interpretación Masto Resultado
# 304116          00:00.0                    45:47.9   Benigna
# 92917           00:00.0                    00:00.0   Benigna
# ...

# %%
df.shape
# Out:
# (855017, 10)

# %%
df_sample.shape
# Out:
# (42751, 10)

# %%
df_dropped = df.dropna(subset=['Fecha Interpretación Masto'])
df_dropped.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
# 1                1  AGUASCALIENTES    57          00:00.0
# 2                1  AGUASCALIENTES    57          00:00.0
# 3                1  AGUASCALIENTES    57          00:00.0
# 4                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto                         Resultado
# 0                    00:00.0  Altamente Sugestiva a Malignidad
# 1                    00:00.0  Altamente Sugestiva a Malignidad
# ...

# %%
df_droppedb = df_dropped.dropna(subset=['Fecha Toma Masto'])
df_droppedb.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
# 1                1  AGUASCALIENTES    57          00:00.0
# 2                1  AGUASCALIENTES    57          00:00.0
# 3                1  AGUASCALIENTES    57          00:00.0
# 4                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto                         Resultado
# 0                    00:00.0  Altamente Sugestiva a Malignidad
# 1                    00:00.0  Altamente Sugestiva a Malignidad
# ...

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
# 1                1  AGUASCALIENTES    57          00:00.0
# 2                1  AGUASCALIENTES    57          00:00.0
# 3                1  AGUASCALIENTES    57          00:00.0
# 4                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto                         Resultado
# 0                    00:00.0  Altamente Sugestiva a Malignidad
# 1                    00:00.0  Altamente Sugestiva a Malignidad
# ...

# %%
df_copy.shape
# Out:
# (855017, 10)

# %%
df_dropped['Resultado'].dtype
# Out:
# dtype('O')

# %%
list(df['Resultado'].unique())
# Out:
# ['Altamente Sugestiva a Malignidad',
#  'Probablemente Benigna',
#  'Evaluación Adicional',
#  'Benigna',
#  'Anormalidad Sospechosa',
#  'Riesgo Intermedio de Malignidad',
#  'Baja Sospecha de Malignidad',
#  'Negativa',
#  'Riesgo Moderado de Malignidad']

# %%
keys = list(df['Resultado'].unique())
vals = range(1,10)
act = dict(zip(keys, vals))
act
# Out:
# {'Altamente Sugestiva a Malignidad': 1,
#  'Probablemente Benigna': 2,
#  'Evaluación Adicional': 3,
#  'Benigna': 4,
#  'Anormalidad Sospechosa': 5,
#  'Riesgo Intermedio de Malignidad': 6,
#  'Baja Sospecha de Malignidad': 7,
#  'Negativa': 8,
#  'Riesgo Moderado de Malignidad': 9}

# %%
df_copy['Resultado'] = df['Resultado'].map(act)
df_copy.head()
# Out:
#    Clave Entidad         Entidad  Clave Jurisdicción    Jurisdicción  \
# 0              1  Aguascalientes                   1  Aguascalientes
# 1              1  Aguascalientes                   1  Aguascalientes
# 2              1  Aguascalientes                   1  Aguascalientes
# 3              1  Aguascalientes                   1  Aguascalientes
# 4              1  Aguascalientes                   1  Aguascalientes
#
#    Clave Municipio       Municipio  Edad Fecha Toma Masto  \
# 0                1  AGUASCALIENTES    57          00:00.0
# 1                1  AGUASCALIENTES    57          00:00.0
# 2                1  AGUASCALIENTES    57          00:00.0
# 3                1  AGUASCALIENTES    57          00:00.0
# 4                1  AGUASCALIENTES    57          00:00.0
#
#   Fecha Interpretación Masto  Resultado
# 0                    00:00.0          1
# 1                    00:00.0          1
# 2                    00:00.0          2
# ...

# %%
list(df_copy['Resultado'].unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
df_copy['Edad'].mean()
# Out:
# 50.756362738986475

# %%
df_copy['Edad'][df_copy['Resultado'] == 6]
# Out:
# 579       51
# 2068      54
# 2070      46
# 2072      51
# 2815      48
# 3321      64
# 3698      51
# 4298      49
# 4299      42
# 4300      44
# 4443      48
# 4446      44
# 4534      44
# 4536      40
# 4578      52
# 4706      62
# 4707      56
# 5033      44
# 5034      51
# 5157      39
# 5158      42
# 13241     50
# 13277     58
# 15807     42
# 22142     57
# 29841     43
# 31051     62
# 31053     51
# 32139     47
# 32140     48
#           ..
# 838645    58
# 840005    47
# 840271    45
# 840508    48
# 841264    52
# 841265    56
# 841858    47
# 843175    45
# 843516    51
# 845874    55
# 846804    55
# 847773    65
# 847831    67
# 847835    54
# 847838    42
# 848141    48
# 848225    42
# 849028    44
# 849029    47
# 849439    60
# 849654    39
# 849655    44
# 849657    48
# 849659    42
# 849756    50
# 849757    59
# 849758    41
# 851034    40
# 852941    65
# 854125    44
# Name: Edad, Length: 753, dtype: int64

# %%
df_copy['Edad'][df_copy['Resultado'] == 6].mean()
# Out:
# 50.90969455511288

# %%
df_copy.groupby(["Resultado", "Edad", "Municipio"]).count()
# Out:
#                                             Clave Entidad  Entidad  \
# Resultado Edad Municipio
# 1         26   CENTRO                                   1        1
#                COYOACAN                                 1        1
#           28   PACHUCA DE SOTO                          1        1
#                SAN FERNANDO                             1        1
#           29   QUERETARO                                1        1
#           30   ANTONIO CARVAJAL                         1        1
#                COYOACAN                                 1        1
#                GUADALUPE                                1        1
#                SAN NICOLAS DE LOS GARZA                 1        1
#                TAMAZUNCHALE                             1        1
#           31   COYOACAN                                 1        1
#                JUAREZ                                   1        1
#                SAN NICOLAS DE LOS GARZA                 3        3
# ...

# %%
df_copy.Resultado
# Out:
# 0         1
# 1         1
# 2         2
# 3         3
# 4         1
# 5         4
# 6         4
# 7         4
# 8         4
# 9         4
# 10        4
# 11        4
# 12        4
# 13        4
# 14        4
# 15        4
# 16        4
# 17        4
# 18        4
# 19        4
# 20        4
# 21        4
# 22        4
# 23        4
# 24        4
# 25        4
# 26        4
# 27        4
# 28        4
# 29        4
#          ..
# 854987    4
# 854988    3
# 854989    3
# 854990    4
# 854991    8
# 854992    4
# 854993    3
# 854994    8
# 854995    8
# 854996    3
# 854997    4
# 854998    4
# 854999    8
# 855000    8
# 855001    4
# 855002    4
# 855003    4
# 855004    4
# 855005    8
# 855006    4
# 855007    8
# 855008    3
# 855009    8
# 855010    8
# 855011    3
# 855012    4
# 855013    3
# 855014    4
# 855015    3
# 855016    4
# Name: Resultado, Length: 855017, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#         Clave Entidad           Entidad  Clave Jurisdicción  \
# 304116             14           Jalisco                   4
# 92917               9  Ciudad de México                   1
# 574505             19        Nuevo León                   1
# 472539             15  Estado de México                  18
# 584796             19        Nuevo León                   4
#
#              Jurisdicción  Clave Municipio          Municipio  Edad  \
# 304116           La Barca               96    TIZAPAN EL ALTO    43
# 92917   Gustavo A. Madero                5  GUSTAVO A. MADERO    45
# 574505          Monterrey               39          MONTERREY    51
# 472539     Nezahualcoyotl               58     NEZAHUALCOYOTL    48
# 584796   Ciudad Guadalupe               26          GUADALUPE    47
#
#        Fecha Toma Masto Fecha Interpretación Masto Resultado
# 304116          00:00.0                    45:47.9   Benigna
# 92917           00:00.0                    00:00.0   Benigna
# ...

# %%
##Data Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
#figure.savefig('.../.jpeg')
#df_sample['ventas'] = dropna()
df_copy['Resultado'] = df_copy['Resultado'].astype('int64')

df_copy.plot(kind='scatter',x='Resultado',y='Edad')

# %%
plt.hist(df_copy['Resultado'])
plt.xlabel('Resultado')
plt.ylabel('Frequency')
plt.title('Frequency of resultados')
# Out:
# Text(0.5, 1.0, 'Frequency of resultados')

# %%
plt.boxplot(df_copy['Resultado'], showmeans=True, meanline=True)
plt.ylabel('Resultado count')
plt.title('Box Plot of Resultado count')
# Out:
# Text(0.5, 1.0, 'Box Plot of Resultado count')
