# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
#https://datos.gob.mx/busca/dataset/estadistica-de-la-produccion-pecuaria
path = 'C:\\Users\\hades\\Downloads\\dataset práctica 1\\cierre_2017.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#      Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 0  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 1  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 2  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 3  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 4  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
#
#      Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 0  Aguascalientes         1.0      Abeja          7.0           Miel
# 1  Aguascalientes         3.0        Ave          1.0          Carne
# 2  Aguascalientes         3.0        Ave          8.0  Ganado en pie
# 3  Aguascalientes         3.0        Ave          4.0    Huevo-plato
# 4  Aguascalientes         4.0     Bovino          1.0          Carne
#
#       Volumen     Peso  Precio        Valor  Asacrificado
# 0     310.521    0.000   45.60    14160.036           0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33365 entries, 0 to 33364
# Data columns (total 16 columns):
# Anio            33364 non-null float64
# Cveestado       33364 non-null float64
# Nomestado       33364 non-null object
# Cveddr          33364 non-null float64
# Nomddr          33364 non-null object
# Cvempio         33364 non-null float64
# Nommunicipio    33364 non-null object
# Cveespecie      33364 non-null float64
# Nomespecie      33364 non-null object
# Cveproducto     33364 non-null float64
# Nomproducto     33364 non-null object
# Volumen         33364 non-null float64
# Peso            33364 non-null float64
# Precio          33364 non-null float64
# Valor           33364 non-null float64
# Asacrificado    33364 non-null float64
# dtypes: float64(11), object(5)
# memory usage: 4.1+ MB

# %%
df.shape
# Out:
# (33365, 16)

# %%
df.shape[0]
# Out:
# 33365

# %%
df.shape[1]
# Out:
# 16

# %%
df.columns.values.tolist()
# Out:
# ['Anio',
#  'Cveestado',
#  'Nomestado',
#  'Cveddr',
#  'Nomddr',
#  'Cvempio',
#  'Nommunicipio',
#  'Cveespecie',
#  'Nomespecie',
#  'Cveproducto',
#  'Nomproducto',
#  'Volumen',
#  'Peso',
#  'Precio',
#  'Valor',
#  'Asacrificado']

# %%
df.dtypes
# Out:
# Anio            float64
# Cveestado       float64
# Nomestado        object
# Cveddr          float64
# Nomddr           object
# Cvempio         float64
# Nommunicipio     object
# Cveespecie      float64
# Nomespecie       object
# Cveproducto     float64
# Nomproducto      object
# Volumen         float64
# Peso            float64
# Precio          float64
# Valor           float64
# Asacrificado    float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Anio',
#  'Cveestado',
#  'Nomestado',
#  'Cveddr',
#  'Nomddr',
#  'Cvempio',
#  'Nommunicipio',
#  'Cveespecie',
#  'Nomespecie',
#  'Cveproducto',
#  'Nomproducto',
#  'Volumen',
#  'Peso',
#  'Precio',
#  'Valor',
#  'Asacrificado']

# %%
df.describe()
# Out:
#           Anio     Cveestado        Cveddr       Cvempio    Cveespecie  \
# count  33364.0  33364.000000  33364.000000  33364.000000  33364.000000
# mean    2017.0     19.351157    104.390361    112.804850      7.008422
# std        0.0      7.210192     46.148441    135.596668      4.427825
# min     2017.0      1.000000      1.000000      1.000000      1.000000
# 25%     2017.0     14.000000     72.000000     24.000000      3.000000
# 50%     2017.0     20.000000    105.000000     58.000000      6.000000
# 75%     2017.0     24.000000    128.000000    138.000000     12.000000
# max     2017.0     32.000000    193.000000    570.000000     14.000000
#
#         Cveproducto        Volumen          Peso        Precio         Valor  \
# count  33364.000000   33364.000000  33364.000000  33364.000000  3.336400e+04
# mean       3.311413     930.626722     64.973957     38.465256  2.061115e+04
# std        2.431832    9076.133896    114.218916     20.428050  1.444663e+05
# ...

# %%
df.loc[[0]]
# Out:
#      Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 0  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
#
#      Nommunicipio  Cveespecie Nomespecie  Cveproducto Nomproducto  Volumen  \
# 0  Aguascalientes         1.0      Abeja          7.0        Miel  310.521
#
#    Peso  Precio      Valor  Asacrificado
# 0   0.0    45.6  14160.036           0.0

# %%
df.loc[30:33]
# Out:
#       Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 30  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      3.0
# 31  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      3.0
# 32  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      3.0
# 33  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      3.0
#
#    Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  Volumen  \
# 30     Calvillo         6.0    Caprino          3.0  Ganado en pie    5.820
# 31     Calvillo        12.0      Ovino          1.0          Carne   12.800
# 32     Calvillo        12.0      Ovino          3.0  Ganado en pie   24.824
# 33     Calvillo        14.0    Porcino          1.0          Carne   61.220
#
#       Peso  Precio     Valor  Asacrificado
# 30  40.699   29.54   171.920           0.0
# 31  23.358   65.82   842.500         548.0
# 32  45.299   34.04   845.010           0.0
# 33  82.730   37.92  2321.458         740.0

# %%
df_dropped = df.dropna(subset=['Anio'])
df_dropped.head()
# Out:
#      Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 0  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 1  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 2  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 3  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 4  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
#
#      Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 0  Aguascalientes         1.0      Abeja          7.0           Miel
# 1  Aguascalientes         3.0        Ave          1.0          Carne
# 2  Aguascalientes         3.0        Ave          8.0  Ganado en pie
# 3  Aguascalientes         3.0        Ave          4.0    Huevo-plato
# 4  Aguascalientes         4.0     Bovino          1.0          Carne
#
#       Volumen     Peso  Precio        Valor  Asacrificado
# 0     310.521    0.000   45.60    14160.036           0.0
# ...

# %%
df.Cveespecie.unique()
# Out:
# array([ 1.,  3.,  4.,  6., 12., 14., 10., nan])

# %%
df.Cveespecie.value_counts()
# Out:
# 4.0     6972
# 3.0     6577
# 12.0    5043
# 14.0    4702
# 6.0     4174
# 10.0    3214
# 1.0     2682
# Name: Cveespecie, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#           Anio  Cveestado  Nomestado  Cveddr  Nomddr  Cvempio  Nommunicipio  \
# count    33364      33364      33364   33364   33364    33364         33364
# size     33365      33365      33365   33365   33365    33365         33365
# nunique      1         32         32     191     191      570          2302
#
#          Cveespecie  Nomespecie  Cveproducto  Nomproducto  Volumen   Peso  \
# count         33364       33364        33364        33364    33364  33364
# size          33365       33365        33365        33365    33365  33365
# nunique           7           7            8            7    26184  19008
#
#          Precio  Valor  Asacrificado
# count     33364  33364         33364
# size      33365  33365         33365
# nunique    7268  32422          5588

# %%
df.groupby('Nomespecie').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     Anio  Cveestado  Nomestado  Cveddr  Nomddr  Cvempio  \
# Nomespecie
# Abeja      count    2682       2682       2682    2682    2682     2682
#            size     2682       2682       2682    2682    2682     2682
#            nunique     1         32         32     161     161      343
# Ave        count    6577       6577       6577    6577    6577     6577
#            size     6577       6577       6577    6577    6577     6577
#            nunique     1         32         32     171     171      570
# Bovino     count    6972       6972       6972    6972    6972     6972
#            size     6972       6972       6972    6972    6972     6972
#            nunique     1         32         32     191     191      551
# Caprino    count    4174       4174       4174    4174    4174     4174
#            size     4174       4174       4174    4174    4174     4174
#            nunique     1         29         29     151     151      526
# ...

# %%
df.groupby('Nomproducto').agg(['count', 'size', 'nunique']).stack()
# Out:
#                         Anio  Cveestado  Nomestado  Cveddr  Nomddr  Cvempio  \
# Nomproducto
# Carne         count    12594      12594      12594   12594   12594    12594
#               size     12594      12594      12594   12594   12594    12594
#               nunique      1         32         32     191     191      570
# Cera          count     1167       1167       1167    1167    1167     1167
#               size      1167       1167       1167    1167    1167     1167
#               nunique      1         26         26     119     119      332
# Ganado en pie count    12594      12594      12594   12594   12594    12594
#               size     12594      12594      12594   12594   12594    12594
#               nunique      1         32         32     191     191      570
# Huevo-plato   count     2147       2147       2147    2147    2147     2147
#               size      2147       2147       2147    2147    2147     2147
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          Anio  Cveestado            Nomestado  Cveddr               Nomddr  \
# 15658  2017.0       20.0               Oaxaca   104.0    Huajuapan de León
# 22261  2017.0       21.0               Puebla   116.0  Izúcar de Matamoros
# 19625  2017.0       20.0               Oaxaca   105.0     Valles Centrales
# 195    2017.0        3.0  Baja California Sur     5.0              Comondú
# 5417   2017.0       12.0             Guerrero    57.0                Tlapa
#
#        Cvempio            Nommunicipio  Cveespecie Nomespecie  Cveproducto  \
# 15658    274.0      San Miguel Piedras        10.0  Guajolote          1.0
# 22261     11.0         Albino Zertuche         6.0    Caprino          3.0
# 19625    158.0  San Jacinto Tlacotepec         4.0     Bovino          6.0
# 195        1.0                 Comondú        12.0      Ovino          1.0
# 5417      78.0      Cochoapa El Grande        10.0  Guajolote          1.0
#
# ...

# %%
df.shape
# Out:
# (33365, 16)

# %%
df_sample.shape
# Out:
# (1668, 16)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#      Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 0  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 1  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 2  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 3  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 4  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
#
#      Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 0  Aguascalientes         1.0      Abeja          7.0           Miel
# 1  Aguascalientes         3.0        Ave          1.0          Carne
# 2  Aguascalientes         3.0        Ave          8.0  Ganado en pie
# 3  Aguascalientes         3.0        Ave          4.0    Huevo-plato
# 4  Aguascalientes         4.0     Bovino          1.0          Carne
#
#       Volumen     Peso  Precio        Valor  Asacrificado
# 0     310.521    0.000   45.60    14160.036           0.0
# ...

# %%
df.Nomproducto.unique()
# Out:
# array(['Miel', 'Carne', 'Ganado en pie', 'Huevo-plato', 'Leche', 'Cera',
#        'Lana', nan], dtype=object)

# %%
df.Cveproducto.unique()
# Out:
# array([ 7.,  1.,  8.,  4.,  3.,  6.,  2.,  5., nan])

# %%
df_copy.groupby(["Cveespecie", "Nomespecie", "Cveproducto", "Nomproducto"]).count()
# Out:
#                                                  Anio  Cveestado  Nomestado  \
# Cveespecie Nomespecie Cveproducto Nomproducto
# 1.0        Abeja      2.0         Cera           1167       1167       1167
#                       7.0         Miel           1515       1515       1515
# 3.0        Ave        1.0         Carne          2215       2215       2215
#                       4.0         Huevo-plato    2147       2147       2147
#                       8.0         Ganado en pie  2215       2215       2215
# 4.0        Bovino     1.0         Carne          2408       2408       2408
#                       3.0         Ganado en pie  2408       2408       2408
#                       6.0         Leche          2156       2156       2156
# 6.0        Caprino    1.0         Carne          1798       1798       1798
#                       3.0         Ganado en pie  1798       1798       1798
#                       6.0         Leche           578        578        578
# ...

# %%
df_copy.groupby(["Cveespecie", "Nomespecie"])[["Cveproducto", "Nomproducto"]].count()
# Out:
#                        Cveproducto  Nomproducto
# Cveespecie Nomespecie
# 1.0        Abeja              2682         2682
# 3.0        Ave                6577         6577
# 4.0        Bovino             6972         6972
# 6.0        Caprino            4174         4174
# 10.0       Guajolote          3214         3214
# 12.0       Ovino              5043         5043
# 14.0       Porcino            4702         4702

# %%
df_copy.Cveespecie
# Out:
# 0         1.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         4.0
# 5         4.0
# 6         4.0
# 7         6.0
# 8         6.0
# 9        12.0
# 10       12.0
# 11       14.0
# 12       14.0
# 13        1.0
# 14        3.0
# 15        3.0
# 16        4.0
# 17        4.0
# 18        4.0
# 19        6.0
# 20        6.0
# 21       12.0
# 22       12.0
# 23       14.0
# 24       14.0
# 25        1.0
# 26        4.0
# 27        4.0
# 28        4.0
# 29        6.0
#          ...
# 33335     1.0
# 33336     3.0
# 33337     3.0
# 33338     3.0
# 33339     4.0
# 33340     4.0
# 33341     4.0
# 33342     6.0
# 33343     6.0
# 33344    12.0
# 33345    12.0
# 33346    12.0
# 33347    14.0
# 33348    14.0
# 33349     1.0
# 33350     1.0
# 33351     3.0
# 33352     3.0
# 33353     3.0
# 33354     4.0
# 33355     4.0
# 33356     4.0
# 33357     6.0
# 33358     6.0
# 33359    12.0
# 33360    12.0
# 33361    12.0
# 33362    14.0
# 33363    14.0
# 33364     NaN
# ...

# %%
df_dropped['Valor'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['Valor'].mean()
# Out:
# 20611.152225542563

# %%
df_copy['Valor'].fillna(value=np.round(df['Valor'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#           Anio  Cveestado  Nomestado  Cveddr  Nomddr  Cvempio  Nommunicipio  \
# count    33364      33364      33364   33364   33364    33364         33364
# size     33365      33365      33365   33365   33365    33365         33365
# nunique      1         32         32     191     191      570          2302
#
#          Cveespecie  Nomespecie  Cveproducto  Nomproducto  Volumen   Peso  \
# count         33364       33364        33364        33364    33364  33364
# size          33365       33365        33365        33365    33365  33365
# nunique           7           7            8            7    26184  19008
#
#          Precio  Valor  Asacrificado
# count     33364  33365         33364
# size      33365  33365         33365
# nunique    7268  32423          5588

# %%
df_copy['Valor'].mean()
# Out:
# 20611.15222098013

# %%
df_copy['Valor'][df_copy['Cveproducto'] == 6]
# Out:
# 6        639452.090
# 18       225814.730
# 28       212028.830
# 40       153798.750
# 52       129488.830
# 65       302842.230
# 77       219644.630
# 89       298565.000
# 101      219044.720
# 111       50888.740
# 123      218602.740
# 136      190776.540
# 145      137215.020
# 153      221937.860
# 165      379513.680
# 177       93649.580
# 180        2120.395
# 191      125002.860
# 194       12323.800
# 204        2459.250
# 215       55718.170
# 218        1396.623
# 229       29017.400
# 238        2193.010
# 241        3594.691
# 267       44292.680
# 270         260.491
# 284        3489.630
# 298        8254.700
# 314       62358.650
#             ...
# 32991      1301.572
# 33006      8754.350
# 33009       282.627
# 33024      5341.580
# 33027       899.790
# 33042    118288.720
# 33045       726.559
# 33060     76519.010
# 33063      1043.331
# 33078      9622.350
# 33081      1214.747
# 33096     55882.800
# 33099      1566.413
# 33112      4823.500
# ...

# %%
df_copy['Valor'][df_copy['Cveproducto'] == 6].mean()
# Out:
# 26148.771528895406

# %%
df_copy.groupby(["Cveproducto", "Nomproducto", "Precio", "Valor"]).count()
# Out:
#                                             Anio  Cveestado  Nomestado  \
# Cveproducto Nomproducto   Precio Valor
# 1.0         Carne         4.78   170.858       1          1          1
#                           5.08   27.294        1          1          1
#                           5.29   202.112       1          1          1
#                           6.45   21.489        1          1          1
#                           9.32   509.241       1          1          1
#                           9.33   31602.217     1          1          1
#                           9.34   2040.612      1          1          1
#                           9.35   9373.388      1          1          1
#                           9.37   7184.295      1          1          1
#                           16.11  2025.172      1          1          1
#                           17.58  21770.627     1          1          1
#                           17.67  116.959       1          1          1
# ...

# %%
df_copy.groupby(["Cveproducto", "Nomproducto"])[["Precio", "Valor"]].count()
# Out:
#                            Precio  Valor
# Cveproducto Nomproducto
# 1.0         Carne           12594  12594
# 2.0         Cera             1167   1167
# 3.0         Ganado en pie    8772   8772
# 4.0         Huevo-plato      2147   2147
# 5.0         Lana              613    613
# 6.0         Leche            2734   2734
# 7.0         Miel             1515   1515
# 8.0         Ganado en pie    3822   3822

# %%
df_copy.Cveproducto
# Out:
# 0        7.0
# 1        1.0
# 2        8.0
# 3        4.0
# 4        1.0
# 5        3.0
# 6        6.0
# 7        1.0
# 8        3.0
# 9        1.0
# 10       3.0
# 11       1.0
# 12       3.0
# 13       7.0
# 14       1.0
# 15       8.0
# 16       1.0
# 17       3.0
# 18       6.0
# 19       1.0
# 20       3.0
# 21       1.0
# 22       3.0
# 23       1.0
# 24       3.0
# 25       7.0
# 26       1.0
# 27       3.0
# 28       6.0
# 29       1.0
#         ...
# 33335    7.0
# 33336    1.0
# 33337    8.0
# 33338    4.0
# 33339    1.0
# 33340    3.0
# 33341    6.0
# 33342    1.0
# 33343    3.0
# 33344    1.0
# 33345    3.0
# 33346    5.0
# 33347    1.0
# 33348    3.0
# 33349    2.0
# 33350    7.0
# 33351    1.0
# 33352    8.0
# 33353    4.0
# 33354    1.0
# 33355    3.0
# 33356    6.0
# 33357    1.0
# 33358    3.0
# 33359    1.0
# 33360    3.0
# 33361    5.0
# 33362    1.0
# 33363    3.0
# 33364    NaN
# Name: Cveproducto, Length: 33365, dtype: float64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          Anio  Cveestado            Nomestado  Cveddr               Nomddr  \
# 15658  2017.0       20.0               Oaxaca   104.0    Huajuapan de León
# 22261  2017.0       21.0               Puebla   116.0  Izúcar de Matamoros
# 19625  2017.0       20.0               Oaxaca   105.0     Valles Centrales
# 195    2017.0        3.0  Baja California Sur     5.0              Comondú
# 5417   2017.0       12.0             Guerrero    57.0                Tlapa
#
#        Cvempio            Nommunicipio  Cveespecie Nomespecie  Cveproducto  \
# 15658    274.0      San Miguel Piedras        10.0  Guajolote          1.0
# 22261     11.0         Albino Zertuche         6.0    Caprino          3.0
# 19625    158.0  San Jacinto Tlacotepec         4.0     Bovino          6.0
# 195        1.0                 Comondú        12.0      Ovino          1.0
# 5417      78.0      Cochoapa El Grande        10.0  Guajolote          1.0
#
# ...

# %%
df_sample.groupby(["Cveproducto", "Nomproducto"])[["Precio", "Valor"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                              Precio                                  Valor  \
#                                 sum       mean count_nonzero           sum
# Cveproducto Nomproducto
# 1.0         Carne          35577.07  53.823101         661.0  1.841660e+07
# 2.0         Cera            4381.72  69.551111          63.0  7.865348e+03
# 3.0         Ganado en pie  13267.86  30.222916         439.0  7.549860e+06
# 4.0         Huevo-plato     2476.10  23.359434         106.0  8.708621e+05
# 5.0         Lana             159.86   4.440556          36.0  9.622700e+02
# 6.0         Leche            727.68   6.114958         119.0  3.729185e+06
# 7.0         Miel            3257.41  47.903088          68.0  8.345408e+04
# 8.0         Ganado en pie   5107.78  29.021477         176.0  5.201343e+06
#
#
#                                    mean count_nonzero
# Cveproducto Nomproducto
# 1.0         Carne          27861.717234         661.0
# 2.0         Cera             124.846794          63.0
# ...

# %%
df_sample.groupby(["Cveproducto", "Nomproducto"]).agg({'Valor':np.mean,'Precio':np.max})
# Out:
#                                   Valor  Precio
# Cveproducto Nomproducto
# 1.0         Carne          27861.717234  124.08
# 2.0         Cera             124.846794  105.04
# 3.0         Ganado en pie  17197.859105   54.51
# 4.0         Huevo-plato     8215.679821   35.71
# 5.0         Lana              26.729722   14.88
# 6.0         Leche          31337.690218    9.83
# 7.0         Miel            1227.265809   74.25
# 8.0         Ganado en pie  29553.085165   56.16

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#figure.savefig('.../.jpeg')
#df_sample['ventas'] = dropna()
df_sample['Valor'] = df_sample['Valor'].astype('int64')

df_sample.plot(kind='scatter',x='Cveproducto',y='Valor')

# %%
plt.hist(df_sample['Cveproducto'])
plt.xlabel('Cveproducto')
plt.ylabel('Frequency')
plt.title('Frequency of Cveproducto')
# Out:
# Text(0.5, 1.0, 'Frequency of Cveproducto')

# %%
plt.hist(df_sample['Precio'])
plt.xlabel('Precio')
plt.ylabel('Frequency')
plt.title('Frequency of $')
# Out:
# Text(0.5, 1.0, 'Frequency of $')

# %%
plt.hist(df_sample['Valor'])
plt.xlabel('Valor')
plt.ylabel('Frequency')
plt.title('Frequency of Valor')
# Out:
# Text(0.5, 1.0, 'Frequency of Valor')

# %%
plt.boxplot(df_sample['Valor'], showmeans=True, meanline=True)
plt.ylabel('Precio count')
plt.title('Box Plot of Precio count')
# Out:
# Text(0.5, 1.0, 'Box Plot of Precio count')
